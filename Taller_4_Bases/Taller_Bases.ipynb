# %%
# !pip install google-cloud-core
# !pip install google-cloud-bigtable
import pandas as pd
import json
# Out:
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\daniel yepes\anaconda3\lib\site-packages)
# ...

# %%
import time
from datetime import datetime as dt

# %%
from google.cloud import bigtable
from google.cloud.bigtable import column_family, row_filters

# %%
INSTANCE_ID = 'bigtable-1'
TABLE_ID = 'Plantas_{}'.format(time.time())

def print_row(row):
    print("Reading data for {}:".format(row.row_key.decode('utf-8')))
    for cf, cols in sorted(row.cells.items()):
        print("Column Family {}".format(cf))
        for col, cells in sorted(cols.items()):
            for cell in cells:
                labels = " [{}]".format(",".join(cell.labels)) \
                    if len(cell.labels) else ""
                print(
                    "\t{}: {} @{}{}".format(col.decode('utf-8'),
                                            cell.value.decode('utf-8'),
                                            cell.timestamp, labels))
    print("")

# %%
client = bigtable.Client.from_service_account_json('unbosque-service-account.json', admin = True)

#requerimiento 2

f = open("Plant_2_Weather_Sensor_Data", "r")
content = f.read()

print(content)

print('Creating the {} table'.format(TABLE_ID))
table = instance.table(TABLE_ID)

if not table.exists():
    table.create()
else:
    print("ERROR: Table {} already exists".format(TABLE_ID))

Plantas = [
    {
        "DATE_TIME": "1/06/2020 6:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "23.470.155.033.333.300",
        "MODULE_TEMPERATURE": "22.829.620.200.000.000",
        "IRRADIATION": "0.0063919369866666667"
    },
    {
        "DATE_TIME": "1/06/2020 6:15",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "23.673.325.103.448.200",
        "MODULE_TEMPERATURE": "23.338.527.344.827.500",
        "IRRADIATION": "0.020901374103448271"
    },
    {
        "DATE_TIME": "1/06/2020 6:30",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "23.979.217.633.333.300",
        "MODULE_TEMPERATURE": "23.886.279.333.333.300",
        "IRRADIATION": "0.046873134166666677"
    },
    {
        "DATE_TIME": "1/06/2020 6:45",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "24.209.690.400.000.000",
        "MODULE_TEMPERATURE": "25.161.978.166.666.600",
        "IRRADIATION": "0.069706667466666677"
    },
    {
        "DATE_TIME": "1/06/2020 7:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "24.567.252.344.827.500",
        "MODULE_TEMPERATURE": "26.587.057.137.931.000",
        "IRRADIATION": "0.064624228620689644"
    },
    {
        "DATE_TIME": "1/06/2020 7:15",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "24.835.614.033.333.300",
        "MODULE_TEMPERATURE": "27.842.000.433.333.300",
        "IRRADIATION": "0.1504371014"
    },
    {
        "DATE_TIME": "1/06/2020 7:30",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "25.361.633.241.379.300",
        "MODULE_TEMPERATURE": "30.208.129.793.103.400",
        "IRRADIATION": "0.16287006586206898"
    },
    {
        "DATE_TIME": "1/06/2020 7:45",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "255.112.201",
        "MODULE_TEMPERATURE": "29.695.339.933.333.300",
        "IRRADIATION": "0.13207047313333334"
    },
    {
        "DATE_TIME": "1/06/2020 8:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "25.689.117.433.333.300",
        "MODULE_TEMPERATURE": "29.606.748.466.666.600",
        "IRRADIATION": "0.161106645"
    },
    {
        "DATE_TIME": "1/06/2020 8:15",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "25.838.382.137.931.000",
        "MODULE_TEMPERATURE": "29.698.359.931.034.400",
        "IRRADIATION": "0.21757411482758623"
    },
    {
        "DATE_TIME": "1/06/2020 8:30",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "2.610.598.753.333.330",
        "MODULE_TEMPERATURE": "30.992.041.066.666.600",
        "IRRADIATION": "0.28162436533333335"
    },
    {
        "DATE_TIME": "1/06/2020 8:45",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "26.785.414.068.965.500",
        "MODULE_TEMPERATURE": "35.383.090.241.379.300",
        "IRRADIATION": "0.547218646551724"
    },
    {
        "DATE_TIME": "1/06/2020 9:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "27.515.931.200.000.000",
        "MODULE_TEMPERATURE": "3.975.073.440.000.000",
        "IRRADIATION": "0.66032114866666691"
    },
    {
        "DATE_TIME": "1/06/2020 9:15",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "28.245.770.233.333.300",
        "MODULE_TEMPERATURE": "41.818.746.799.999.900",
        "IRRADIATION": "0.69873647966666663"
    },
    {
        "DATE_TIME": "1/06/2020 9:30",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "2.905.904",
        "MODULE_TEMPERATURE": "46.360.684.137.931.000",
        "IRRADIATION": "0.8137932979310345"
    },
    {
        "DATE_TIME": "1/06/2020 9:45",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "29.394.693.966.666.600",
        "MODULE_TEMPERATURE": "49.350.602.266.666.600",
        "IRRADIATION": "0.78834436066666669"
    },
    {
        "DATE_TIME": "1/06/2020 10:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "29.301.692.551.724.100",
        "MODULE_TEMPERATURE": "47.559.440.862.068.900",
        "IRRADIATION": "0.62547622482758614"
    },
    {
        "DATE_TIME": "1/06/2020 10:15",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "29.822.622.499.999.900",
        "MODULE_TEMPERATURE": "504.896.434",
        "IRRADIATION": "0.91844809533333327"
    },
    {
        "DATE_TIME": "1/06/2020 10:30",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "30.160.547.758.620.600",
        "MODULE_TEMPERATURE": "4.979.540.931.034.480",
        "IRRADIATION": "0.68838622827586193"
    },
    {
        "DATE_TIME": "1/06/2020 10:45",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "30.099.529.033.333.300",
        "MODULE_TEMPERATURE": "439.329.496",
        "IRRADIATION": "0.31999971466666655"
    },
    {
        "DATE_TIME": "1/06/2020 11:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "30.165.436.866.666.600",
        "MODULE_TEMPERATURE": "41.236.209.033.333.300",
        "IRRADIATION": "0.31675462433333335"
    },
    {
        "DATE_TIME": "1/06/2020 11:15",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "30.597.649.999.999.900",
        "MODULE_TEMPERATURE": "43.203.521.793.103.400",
        "IRRADIATION": "0.45434183068965517"
    },
    {
        "DATE_TIME": "1/06/2020 11:30",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "309.631.358",
        "MODULE_TEMPERATURE": "43.168.145.766.666.600",
        "IRRADIATION": "0.35262523700000004"
    },
    {
        "DATE_TIME": "1/06/2020 11:45",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "30.702.194.655.172.400",
        "MODULE_TEMPERATURE": "39.678.807.931.034.400",
        "IRRADIATION": "0.48591024379310349"
    },
    {
        "DATE_TIME": "1/06/2020 12:00",
        "PLANT_ID": "4136001",
        "SOURCE_KEY": "iq8k7ZNt4Mwm3w0",
        "AMBIENT_TEMPERATURE": "32.097.253.366.666.600",
        "MODULE_TEMPERATURE": "53.477.917.500.000.000",
        "IRRADIATION": "10.797.786.666.666.600"
    }
]

print(Plantas.read)

# requerimiento 3

f_1 = open("Plant_1_Generation_Data.json", "r")
content_1 = f.read()

print(content_1)

row_set = RowSet()
    row_set.add_row_range_from_keys(
        start_key="adLQvlD726eNBSB1"
    )
# Out:
#   File "C:\Users\DANIEL~1\AppData\Local\Temp/ipykernel_7872/2050266506.py", line 231
#     row_set.add_row_range_from_keys(
#     ^
# IndentationError: unexpected indent
